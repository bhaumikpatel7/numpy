# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri)
plt.show()

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue='event')
plt.show()

# %%
sns.lineplot(x="timepoint",y='signal',data=fmri,hue='event',style='event',markers=True)
plt.show()

# %%
import pandas as pd

# %%
iris=pd.read_csv('/Users/khusali/Downloads/archive/iris.csv')

# %%
iris.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,hue='Species')
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,hue='PetalLengthCm')
plt.show()

# %%
diamonds=pd.read_csv('/Users/khusali/Downloads/diamonds.csv')

# %%
diamonds.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
# 7  4.11  2.53
# 8  3.78  2.49
# ...

# %%
sns.distplot(diamonds['price'])
plt.show()
# Out:
# /Users/khusali/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],hist=False)
plt.show()
# Out:
# /Users/khusali/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],color='g',hist=False)
plt.show()
# Out:
# /Users/khusali/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],kde=False)
plt.show()
# Out:
# /Users/khusali/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds['price'],kde=False,bins=20)
plt.show()

# %%
sns.distplot(diamonds['price'],kde=False,bins=10)
plt.show()

# %%
sns.distplot(diamonds['price'],kde=False,bins=5)
plt.show()

# %%
sns.distplot(diamonds['price'],vertical=True)
plt.show()
# Out:
# /Users/khusali/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=iris)
plt.show()

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,color='r')
plt.show()

# %%
sns.jointplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,color='r',kind='reg')
plt.show()

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=iris,linewidth=5)
plt.show()

# %%
sns.boxplot(x='Species',y='PetalLengthCm',data=iris)
plt.show()

# %%
df=sns.load_dataset('iris') #pair-plot

# %%
sns.pairplot(df,hue='species')
plt.show()
